# %%
import numpy
import os
import json
import csv
import pandas as pd
import numpy as np
np.random.seed(42)

# %%
path = "../../data"

# %%
file = "155_output.csv"

# %%
data = pd.read_csv(os.path.join(path,file),header=None)
unbalancedData = pd.read_csv(os.path.join(path,file),header=None)

# %%
data.head()
# Out:
#                                0         1         2         3         4    \
# 0      Kuntal-01234567891011121314 -1.647343 -1.956522 -1.562802 -1.115942
# 1     Kuntal-123456789101112131415 -2.745819 -3.035117 -3.526756 -1.448161
# 2    Kuntal-2345678910111213141516 -1.618333 -1.761667 -1.893333 -1.003333
# 3   Kuntal-34567891011121314151617 -2.436242 -2.174497 -2.374161 -0.748322
# 4  Kuntal-456789101112131415161718 -1.081940 -1.645485 -1.613712 -0.735786
#
#         5         6         7           8         9   ...        247  \
# 0 -1.084541 -1.118357 -0.971014  127.000000 -0.979311 ...  -0.974107
# 1 -1.683946 -0.836120 -0.968227  -32.822742 -0.980840 ...  -0.968620
# 2 -0.115000 -0.823333 -0.950000 -122.951667 -0.979620 ...  -0.969767
# 3 -0.817114 -0.701342 -0.877517 -127.332215 -0.976527 ...  -0.969813
# 4 -0.476589 -0.551839 -0.946488   -1.994983 -0.971327 ...  -0.965221
#
#         248       249       250       251       252       253       254  \
# 0  0.135282  0.075168 -0.164765 -0.284128  0.114503 -0.953859 -2.047356
# 1  0.148120  0.071493 -0.186080 -0.311107  0.090873 -0.946353 -0.615007
# 2  0.141327  0.077840 -0.182693 -0.297033  0.109987 -0.948740 -1.412507
# 3  0.135200  0.079667 -0.186593 -0.286800  0.115673 -0.951233 -1.129173
# 4  0.144201  0.077866 -0.203309 -0.306201  0.102866 -0.947826 -1.374168
#
#         255  256
# 0  0.502973    0
# 1 -0.347080    0
# 2 -0.042927    0
# 3 -1.361653    0
# 4  0.086832    0
#
# [5 rows x 257 columns]

# %%
mins = data.min().values

# %%
mins[1:18],mins[19:36],mins[37:54]
# Out:
# (array([-128.0, -128.0, -128.0, -128.0, -128.0, -128.0, -128.0, -128.0,
#         -0.9962333333333336, -0.9980135135135147, -0.9990536912751669,
#         -0.9969848484848488, -1.0351006711409396, -1.0888399999999996,
#         -1.0576778523489938, -72.26845637583892, -92.37037333333332],
#        dtype=object),
#  array([-128.0, -128.0, -128.0, -128.0, -128.0, -128.0, -128.0,
#         -0.9962333333333336, -0.9980135135135147, -0.9990536912751669,
#         -0.9969848484848488, -1.0351006711409396, -1.0888399999999996,
#         -1.0576778523489938, -72.26845637583892, -92.37037333333332,
#         -128.0], dtype=object),
#  array([-128.0, -128.0, -128.0, -128.0, -128.0, -128.0,
#         -0.9962333333333336, -0.9980135135135147, -0.9990536912751669,
#         -0.9969848484848488, -1.0351006711409396, -1.0888399999999996,
#         -1.0576778523489938, -72.26845637583892, -92.37037333333332,
#         -128.0, -128.0], dtype=object))

# %%
maxs = data.max().values
maxs[1:18],maxs[19:36],maxs[37:54]
# Out:
# (array([127.0, 104.23745819397993, 127.0, 77.01520270270271, 127.0, 127.0,
#         127.0, 127.0, 0.9982600000000004, 0.994000000000004,
#         0.9937066666666676, 0.9988333333333312, 1.0430067567567571, 1.107,
#         1.0143154362416105, 75.6648523489933, 80.64663999999998],
#        dtype=object),
#  array([104.23745819397993, 127.0, 77.01520270270271, 127.0, 127.0, 127.0,
#         127.0, 0.9982600000000004, 0.994000000000004, 0.9937066666666676,
#         0.9988333333333312, 1.0430067567567571, 1.107, 1.0143154362416105,
#         75.6648523489933, 80.64663999999998, 127.0], dtype=object),
#  array([127.0, 77.01520270270271, 127.0, 127.0, 127.0, 127.0,
#         0.9982600000000004, 0.994000000000004, 0.9937066666666676,
#         0.9988333333333312, 1.0430067567567571, 1.107, 1.0143154362416105,
#         75.6648523489933, 80.64663999999998, 127.0, 104.23745819397993],
#        dtype=object))

# %%
for index,mx in enumerate(maxs):
    if mx == 1:
        print(index,mx)
for index,mx in enumerate(mins):
    if mx == 0:
        print(index,mx)
# Out:
# 256 1
# 256 0

# %%
data.describe()
# Out:
#                 1             2             3             4             5    \
# count  77610.000000  77610.000000  77610.000000  77610.000000  77610.000000
# mean      -0.777750     -0.873237     -0.876502     -1.009098     -1.036980
# std        3.776450      2.453478      3.590824      2.561039      3.589899
# min     -128.000000   -128.000000   -128.000000   -128.000000   -128.000000
# 25%       -1.164983     -1.209030     -1.332776     -1.179435     -1.294314
# 50%       -0.956229     -0.979730     -1.031879     -0.973018     -1.058575
# 75%       -0.695652     -0.777778     -0.744147     -0.739865     -0.801918
# max      127.000000    104.237458    127.000000     77.015203    127.000000
#
#                 6             7             8             9             10   \
# count  77610.000000  77610.000000  77610.000000  77610.000000  77610.000000
# mean      -1.163190     -0.914270      2.348799      0.009414      0.003666
# std        3.651997      3.555194     18.516635      0.616896      0.310521
# min     -128.000000   -128.000000   -128.000000     -0.996233     -0.998014
# 25%       -1.272727     -1.205686     -1.111667     -0.578673     -0.192158
# 50%       -1.010169     -0.996371     -0.595478      0.012594      0.009157
# 75%       -0.711667     -0.747492      2.682274      0.585530      0.172812
# max      127.000000    127.000000    127.000000      0.998260      0.994000
#
#            ...                247           248           249           250  \
# count      ...       77610.000000  77610.000000  77610.000000  77610.000000
# mean       ...           0.009512      0.003806      0.021043      0.017800
# std        ...           0.616676      0.310636      0.343461      0.624007
# min        ...          -0.996233     -0.998014     -0.999054     -0.996985
# 25%        ...          -0.578244     -0.192107     -0.184990     -0.556585
# 50%        ...           0.012793      0.009208      0.030000      0.008047
# 75%        ...           0.585411      0.173038      0.220161      0.620057
# max        ...           0.998260      0.994000      0.993707      0.998833
#
#                 251           252           253           254           255  \
# count  77610.000000  77610.000000  77610.000000  77610.000000  77610.000000
# mean       0.073361     -0.008104     -0.560612     -1.872624     -0.345534
# std        0.454987      0.464988      0.505890      6.835359      6.606245
# min       -1.035101     -1.088840     -1.057678    -72.268456    -92.370373
# 25%       -0.254042     -0.306719     -0.917740     -3.082077     -0.974335
# 50%        0.088271      0.011110     -0.772933     -1.447597     -0.251203
# 75%        0.405794      0.286456     -0.363779     -1.071767      0.252965
# max        1.043007      1.107000      1.014315     75.664852     80.646640
#
#                 256
# count  77610.000000
# mean       0.040987
# std        0.198261
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
#
# [8 rows x 256 columns]

# %%
noneatData = data[data[data.columns[256]]==0]

# %%
eatData = data[data[data.columns[256]]==1]

# %%
print(noneatData.shape,eatData.shape)
# Out:
# (74429, 257) (3181, 257)

# %%
noneatData = noneatData.sample(n=3181)

# %%
print(noneatData.shape,eatData.shape)
# Out:
# (3181, 257) (3181, 257)

# %% [markdown]
# ### Data Vectorization

# %%
data = pd.concat([noneatData,eatData])

# %%
X_data = np.array(data[data.columns[1:256]].values.tolist())
X_unbalancedData = np.array(unbalancedData[unbalancedData.columns[1:256]].values.tolist())

# %%
#data[data.columns[134]].head()
X_data[0].shape
# Out:
# (255,)

# %%
print (X_data.shape,X_unbalancedData.shape)
# Out:
# (6362, 255) (77610, 255)

# %%
Y_data = np.array(data[data.columns[256]].values.tolist())
Y_unbalancedData = np.array(unbalancedData[unbalancedData.columns[256]].values.tolist())

# %%
print(Y_data.shape,Y_unbalancedData.shape)
# Out:
# (6362,) (77610,)

# %% [markdown]
# ### Feature Selection

# %% [markdown]
# #### L1-based feature selection

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.svm import LinearSVC

# %%
lsvc = LinearSVC(C=0.01, penalty="l1", dual=False).fit(X_data, Y_data)
model = SelectFromModel(lsvc, prefit=True)
X_new = model.transform(X_data)
X_new.shape
# Out:
# (6362, 124)

# %% [markdown]
# #### Tree-based feature selection (Works very good)

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.feature_selection import SelectFromModel

clfTree = ExtraTreesClassifier(n_estimators=50)
clfTree = clfTree.fit(X_data, Y_data)
print (clfTree.feature_importances_)  

model = SelectFromModel(clfTree, prefit=True)
X_new = model.transform(X_data)
print (X_new.shape)
# Out:
# /Users/shailajasampat/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# [0.00220595 0.00187154 0.0023357  0.0012934  0.00208733 0.00187901
#  0.00203568 0.00518414 0.00975163 0.00350883 0.00414649 0.00651813
#  0.00443107 0.00399678 0.00665799 0.00163901 0.00160728 0.00136269
#  0.0018966  0.0023411  0.00191443 0.00189808 0.00219523 0.00265533
#  0.00427672 0.00616641 0.00419586 0.00404264 0.00487735 0.00888416
#  0.00407865 0.00749121 0.00183538 0.00140991 0.00156654 0.00170821
#  0.00229935 0.00145468 0.00154676 0.00186327 0.00246126 0.00474152
#  0.01758256 0.00387963 0.00382921 0.00456689 0.00707558 0.00436261
#  0.00548158 0.00169882 0.00174673 0.00150336 0.00213066 0.00266481
#  0.00192954 0.00144564 0.00201297 0.00207051 0.00495701 0.01844177
#  0.0028004  0.00519346 0.00500207 0.00492287 0.00493581 0.00480551
#  0.0020968  0.0021233  0.00120921 0.00190736 0.00284718 0.00194219
#  0.00203016 0.00275084 0.00201055 0.00598884 0.0156153  0.00321805
#  0.00451781 0.00575535 0.00674411 0.00462722 0.00982145 0.00206959
#  0.00159125 0.00165182 0.0023521  0.00300408 0.00191144 0.00146887
#  0.00207695 0.00200946 0.00440877 0.00912865 0.00402949 0.00327588
#  0.00515229 0.00584359 0.00426899 0.00715487 0.00142694 0.00167801
#  0.0014676  0.00197191 0.00269833 0.00179284 0.00192565 0.00190435
#  0.00182512 0.00666925 0.01418965 0.00274396 0.00456305 0.00392461
#  0.00550473 0.00507145 0.00706976 0.00208046 0.00186315 0.00141411
#  0.00196338 0.00196727 0.00179622 0.00186458 0.00187815 0.00236114
#  0.00557158 0.01116564 0.00365231 0.0041558  0.00567371 0.00534251
#  0.00410096 0.00606232 0.00153217 0.0018558  0.00117373 0.00186486
#  0.00212188 0.00173524 0.00168685 0.00206574 0.00196353 0.00613214
#  0.00994499 0.00408542 0.00428791 0.0045937  0.00603012 0.00433993
#  0.00670198 0.0017328  0.001929   0.00113862 0.00263871 0.0026661
#  0.00171264 0.00138751 0.00192754 0.00228006 0.00527537 0.01355739
#  0.00484065 0.00469837 0.00450589 0.00510905 0.00451961 0.00772252
#  0.00197644 0.00160452 0.00137424 0.00198306 0.00246372 0.00157448
#  0.00129396 0.00163718 0.00234062 0.00488511 0.0170064  0.00289627
#  0.00396905 0.00643601 0.00527246 0.00465247 0.00483055 0.00181074
#  0.0021554  0.00135767 0.00242465 0.00256209 0.00176678 0.00208801
#  0.0024269  0.00239554 0.00508677 0.01390201 0.00417018 0.00457603
#  0.00441368 0.00526492 0.00420598 0.00468015 0.00165801 0.00174034
#  0.00148832 0.00171291 0.00260455 0.0015212  0.00179195 0.00193528
#  0.00199013 0.00454002 0.01520176 0.0035882  0.00427676 0.00687928
#  0.00623481 0.00477493 0.00981868 0.00206617 0.00200376 0.0013857
#  0.00239298 0.0026672  0.00206982 0.001959   0.00209026 0.00198117
#  0.00472995 0.00864299 0.00532072 0.00461062 0.00600869 0.00653427
#  0.00455627 0.00614947 0.00205087 0.00209825 0.0015833  0.00263709
#  0.00272433 0.00180392 0.00220495 0.0018771  0.00211019 0.00511377
#  0.0178731  0.00423058 0.00573514 0.00473849 0.00621497 0.00614079
#  0.00732555 0.00206434 0.00200756]
# (6362, 110)

# %%
X_unbalanced_new = model.transform(X_unbalancedData)
print(X_unbalanced_new.shape)
# Out:
# (77610, 110)

# %% [markdown]
# ### Classification

# %%
#from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()

# %%
#clf = XGBClassifier(n_jobs=-1,verbosity=2)

# %%
X_new = X_data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_new, Y_data, test_size=0.30, random_state=42, shuffle =True)

# %%
print (y_train)
# Out:
# [1 1 1 ... 1 1 0]

# %%
X_train[-1],X_train[-2],y_train[-1],y_train[-2]
# Out:
# (array([-1.05192630e+00, -1.43383585e+00, -1.02512563e+00, -1.01005025e+00,
#         -1.16917923e+00, -1.64991625e+00, -1.95142379e+00, -1.27135678e+00,
#         -2.23453333e-01, -9.06746667e-01, -1.20526667e-01,  3.36533333e-01,
#         -1.03703704e+00, -1.16161616e+00, -1.56902357e+00, -2.25252525e+00,
#         -9.22558923e-01, -1.54545455e+00,  3.33215488e+01, -7.34364238e-01,
#         -6.12913907e-01, -1.32463576e-01,  1.61450331e-01,  9.07059603e-01,
#         -3.87655629e-01, -1.20768212e-01,  2.84561192e+01, -5.37750993e+00,
#          8.08080808e-02, -2.20538721e-01,  7.13804714e-01, -1.71548822e+00,
#         -4.59595960e-01, -2.88215488e+00, -1.56734007e+00,  3.33922559e+01,
#         -7.68228188e-01, -5.64993289e-01,  4.87516779e-02,  1.98657718e-01,
#          9.26651007e-01, -1.27577181e-01, -2.28489933e-01, -1.35721007e+01,
#         -3.39306711e+00, -6.45973154e-01, -4.88255034e-01, -9.63087248e-01,
#         -9.19463087e-01, -3.47315436e-01, -9.78187919e-01, -3.38926174e-01,
#         -1.09060403e+00, -8.10080000e-01, -5.23193333e-01,  7.34400000e-02,
#          1.97053333e-01,  9.05600000e-01, -1.04973333e-01, -3.52240000e-01,
#          1.57099800e+01, -3.35669333e+00, -1.63513514e+00, -1.21283784e+00,
#         -2.33445946e+00, -7.26351351e-01, -2.68581081e-01,  5.33783784e-01,
#         -7.82094595e-01,  1.58074324e+01, -7.07393333e-01, -5.46466667e-01,
#          1.40380000e-01,  3.33693333e-01,  9.47133333e-01, -1.60586667e-01,
#         -2.00993333e-01, -5.57093333e-01,  1.53379200e+01]),
#  0,
#  1)

# %%
clf.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
from sklearn.metrics import accuracy_score
preds_val = clf.predict(X_test)
accuracy = accuracy_score(y_test, preds_val)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 66.68%

# %% [markdown]
# #### Parameter Search by GridSearch

# %%
from sklearn.model_selection import GridSearchCV

def LR_param_selection(XData, yData, nfolds):
    #param_grid = {'n_estimators':(100,100,1000),'max_depth': range(1, 20, 5)}
    param_grid = {'penalty':['l1','l2'],'C': np.logspace(-4, 4, 10) }
    #grid_search = GridSearchCV(XGBClassifier(cache_size=2000), param_grid, cv=nfolds, n_jobs=-1, verbose=2)
    grid_search = GridSearchCV(LogisticRegression(), param_grid, cv=nfolds, n_jobs=-1, verbose=2)
    grid_search.fit(XData, yData)
    grid_search.best_params_
    return grid_search.best_params_
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked',)).History will not be written to the database.

# %%
best_params = LR_param_selection(X_train,y_train,5)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV] C=0.0001, penalty=l1 ............................................
# [CV] C=0.0001, penalty=l1 ............................................
# [CV] C=0.0001, penalty=l1 ............................................
# [CV] C=0.0001, penalty=l1 ............................................
# [CV] ............................. C=0.0001, penalty=l1, total=   0.7s
# [CV] ............................. C=0.0001, penalty=l1, total=   0.9s
# [CV] ............................. C=0.0001, penalty=l1, total=   0.9s
# [CV] C=0.0001, penalty=l1 ............................................
# [CV] C=0.0001, penalty=l2 ............................................
# [CV] ............................. C=0.0001, penalty=l1, total=   0.9s
# [CV] C=0.0001, penalty=l2 ............................................
# [CV] C=0.0001, penalty=l2 ............................................
# [CV] ............................. C=0.0001, penalty=l1, total=   0.4s
# [CV] C=0.0001, penalty=l2 ............................................
# [CV] ............................. C=0.0001, penalty=l2, total=   0.5s
# [CV] ............................. C=0.0001, penalty=l2, total=   0.8s
# [CV] C=0.0001, penalty=l2 ............................................
# [CV] C=0.000774263682681127, penalty=l1 ..............................
# [CV] ............................. C=0.0001, penalty=l2, total=   1.0s
# [CV] ............................. C=0.0001, penalty=l2, total=   0.9s
# [CV] C=0.000774263682681127, penalty=l1 ..............................
# [CV] C=0.000774263682681127, penalty=l1 ..............................
# [CV] ............... C=0.000774263682681127, penalty=l1, total=   0.2s
# [CV] ............... C=0.000774263682681127, penalty=l1, total=   0.3s
# [CV] C=0.000774263682681127, penalty=l1 ..............................
# [CV] C=0.000774263682681127, penalty=l1 ..............................
# [CV] ............... C=0.000774263682681127, penalty=l1, total=   0.3s
# [CV] C=0.000774263682681127, penalty=l2 ..............................
# [CV] ............... C=0.000774263682681127, penalty=l1, total=   0.3s
# [CV] ............... C=0.000774263682681127, penalty=l1, total=   0.3s
# [CV] C=0.000774263682681127, penalty=l2 ..............................
# [CV] C=0.000774263682681127, penalty=l2 ..............................
# [CV] ............................. C=0.0001, penalty=l2, total=   1.0s
# [CV] C=0.000774263682681127, penalty=l2 ..............................
# [CV] ............... C=0.000774263682681127, penalty=l2, total=   1.9s
# [CV] C=0.000774263682681127, penalty=l2 ..............................
# [CV] ............... C=0.000774263682681127, penalty=l2, total=   2.3s
# [CV] C=0.005994842503189409, penalty=l1 ..............................
# [CV] ............... C=0.000774263682681127, penalty=l2, total=   2.3s
# [CV] C=0.005994842503189409, penalty=l1 ..............................
# [CV] ............... C=0.000774263682681127, penalty=l2, total=   2.2s
# [CV] C=0.005994842503189409, penalty=l1 ..............................
# [CV] ............... C=0.005994842503189409, penalty=l1, total=   0.8s
# [CV] C=0.005994842503189409, penalty=l1 ..............................
# [CV] ............... C=0.005994842503189409, penalty=l1, total=   0.9s
# [CV] C=0.005994842503189409, penalty=l1 ..............................
# [CV] ............... C=0.005994842503189409, penalty=l1, total=   1.0s
# [CV] C=0.005994842503189409, penalty=l2 ..............................
# [CV] ............... C=0.000774263682681127, penalty=l2, total=   2.1s
# [CV] C=0.005994842503189409, penalty=l2 ..............................
# [CV] ............... C=0.005994842503189409, penalty=l1, total=   0.9s
# [CV] C=0.005994842503189409, penalty=l2 ..............................
# [CV] ............... C=0.005994842503189409, penalty=l1, total=   0.9s
# [CV] C=0.005994842503189409, penalty=l2 ..............................
# [CV] ............... C=0.005994842503189409, penalty=l2, total=   2.6s
# [CV] C=0.005994842503189409, penalty=l2 ..............................
# [CV] ............... C=0.005994842503189409, penalty=l2, total=   2.8s
# [CV] C=0.046415888336127774, penalty=l1 ..............................
# [CV] ............... C=0.005994842503189409, penalty=l2, total=   2.8s
# [CV] C=0.046415888336127774, penalty=l1 ..............................
# [CV] ............... C=0.005994842503189409, penalty=l2, total=   3.0s
# [CV] C=0.046415888336127774, penalty=l1 ..............................
# [CV] ............... C=0.046415888336127774, penalty=l1, total=   1.3s
# [CV] C=0.046415888336127774, penalty=l1 ..............................
# [CV] ............... C=0.046415888336127774, penalty=l1, total=   1.6s
# [CV] C=0.046415888336127774, penalty=l1 ..............................
# [CV] ............... C=0.005994842503189409, penalty=l2, total=   2.6s
# [CV] ............... C=0.046415888336127774, penalty=l1, total=   2.0s
# [CV] C=0.046415888336127774, penalty=l2 ..............................
# [CV] C=0.046415888336127774, penalty=l2 ..............................
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   12.6s
# [CV] ............... C=0.046415888336127774, penalty=l1, total=   1.9s
# [CV] C=0.046415888336127774, penalty=l2 ..............................
# [CV] ............... C=0.046415888336127774, penalty=l1, total=   1.4s
# [CV] C=0.046415888336127774, penalty=l2 ..............................
# [CV] ............... C=0.046415888336127774, penalty=l2, total=   7.0s
# [CV] C=0.046415888336127774, penalty=l2 ..............................
# [CV] ............... C=0.046415888336127774, penalty=l2, total=   6.3s
# [CV] C=0.3593813663804626, penalty=l1 ................................
# [CV] ............... C=0.046415888336127774, penalty=l2, total=   7.2s
# [CV] C=0.3593813663804626, penalty=l1 ................................
# [CV] ............... C=0.046415888336127774, penalty=l2, total=   9.3s
# [CV] C=0.3593813663804626, penalty=l1 ................................
# [CV] ................. C=0.3593813663804626, penalty=l1, total=   3.2s
# [CV] C=0.3593813663804626, penalty=l1 ................................
# [CV] ................. C=0.3593813663804626, penalty=l1, total=   3.3s
# [CV] C=0.3593813663804626, penalty=l1 ................................
# [CV] ................. C=0.3593813663804626, penalty=l1, total=   3.0s
# [CV] C=0.3593813663804626, penalty=l2 ................................
# [CV] ................. C=0.3593813663804626, penalty=l1, total=   2.4s
# [CV] C=0.3593813663804626, penalty=l2 ................................
# [CV] ............... C=0.046415888336127774, penalty=l2, total=   6.8s
# [CV] C=0.3593813663804626, penalty=l2 ................................
# [CV] ................. C=0.3593813663804626, penalty=l1, total=   2.7s
# [CV] C=0.3593813663804626, penalty=l2 ................................
# [CV] ................. C=0.3593813663804626, penalty=l2, total=  12.9s
# [CV] C=0.3593813663804626, penalty=l2 ................................
# [CV] ................. C=0.3593813663804626, penalty=l2, total=  12.8s
# [CV] C=2.782559402207126, penalty=l1 .................................
# [CV] ................. C=0.3593813663804626, penalty=l2, total=  15.6s
# [CV] C=2.782559402207126, penalty=l1 .................................
# [CV] ................. C=0.3593813663804626, penalty=l2, total=  15.0s
# [CV] C=2.782559402207126, penalty=l1 .................................
# [CV] .................. C=2.782559402207126, penalty=l1, total=   4.3s
# [CV] C=2.782559402207126, penalty=l1 .................................
# [CV] .................. C=2.782559402207126, penalty=l1, total=   4.4s
# [CV] C=2.782559402207126, penalty=l1 .................................
# [CV] .................. C=2.782559402207126, penalty=l1, total=   5.5s
# [CV] C=2.782559402207126, penalty=l2 .................................
# [CV] .................. C=2.782559402207126, penalty=l1, total=   5.2s
# [CV] .................. C=2.782559402207126, penalty=l1, total=   4.5s
# [CV] C=2.782559402207126, penalty=l2 .................................
# [CV] C=2.782559402207126, penalty=l2 .................................
# [CV] ................. C=0.3593813663804626, penalty=l2, total=  13.1s
# [CV] C=2.782559402207126, penalty=l2 .................................
# [CV] .................. C=2.782559402207126, penalty=l2, total=  21.2s
# [CV] C=2.782559402207126, penalty=l2 .................................
# [CV] .................. C=2.782559402207126, penalty=l2, total=  26.8s
# [CV] C=21.54434690031882, penalty=l1 .................................
# [CV] .................. C=2.782559402207126, penalty=l2, total=  22.0s
# [CV] C=21.54434690031882, penalty=l1 .................................
# [CV] .................. C=2.782559402207126, penalty=l2, total=  25.8s
# [CV] C=21.54434690031882, penalty=l1 .................................
# [CV] .................. C=21.54434690031882, penalty=l1, total=   7.7s
# [CV] C=21.54434690031882, penalty=l1 .................................
# [CV] .................. C=21.54434690031882, penalty=l1, total=   8.0s
# [CV] C=21.54434690031882, penalty=l1 .................................
# [CV] .................. C=21.54434690031882, penalty=l1, total=   7.1s
# [CV] C=21.54434690031882, penalty=l2 .................................
# [CV] .................. C=21.54434690031882, penalty=l1, total=   5.0s
# [CV] C=21.54434690031882, penalty=l2 .................................
# [CV] .................. C=21.54434690031882, penalty=l1, total=   5.2s
# [CV] C=21.54434690031882, penalty=l2 .................................
# [CV] .................. C=2.782559402207126, penalty=l2, total=  22.5s
# [CV] C=21.54434690031882, penalty=l2 .................................
# [CV] .................. C=21.54434690031882, penalty=l2, total=  26.5s
# [CV] C=21.54434690031882, penalty=l2 .................................
# [CV] .................. C=21.54434690031882, penalty=l2, total=  27.6s
# [CV] C=166.81005372000558, penalty=l1 ................................
# [CV] .................. C=21.54434690031882, penalty=l2, total=  22.6s
# [CV] .................. C=21.54434690031882, penalty=l2, total=  28.7s
# [CV] C=166.81005372000558, penalty=l1 ................................
# [CV] C=166.81005372000558, penalty=l1 ................................
# [CV] ................. C=166.81005372000558, penalty=l1, total=   9.2s
# [CV] C=166.81005372000558, penalty=l1 ................................
# [CV] ................. C=166.81005372000558, penalty=l1, total=   8.3s
# [CV] C=166.81005372000558, penalty=l1 ................................
# [CV] ................. C=166.81005372000558, penalty=l1, total=   8.6s
# [CV] C=166.81005372000558, penalty=l2 ................................
# [CV] ................. C=166.81005372000558, penalty=l1, total=   8.4s
# [CV] C=166.81005372000558, penalty=l2 ................................
# [CV] ................. C=166.81005372000558, penalty=l1, total=   8.1s
# [CV] C=166.81005372000558, penalty=l2 ................................
# [CV] .................. C=21.54434690031882, penalty=l2, total=  26.1s
# [CV] C=166.81005372000558, penalty=l2 ................................
# [CV] ................. C=166.81005372000558, penalty=l2, total=  36.1s
# [CV] C=166.81005372000558, penalty=l2 ................................
# [CV] ................. C=166.81005372000558, penalty=l2, total=  34.5s
# [CV] C=1291.5496650148827, penalty=l1 ................................
# [CV] ................. C=166.81005372000558, penalty=l2, total=  35.6s
# [CV] C=1291.5496650148827, penalty=l1 ................................
# [CV] ................. C=166.81005372000558, penalty=l2, total=  33.9s
# [CV] C=1291.5496650148827, penalty=l1 ................................
# [CV] ................. C=1291.5496650148827, penalty=l1, total=   8.1s
# [CV] C=1291.5496650148827, penalty=l1 ................................
# [CV] ................. C=1291.5496650148827, penalty=l1, total=   7.4s
# [CV] C=1291.5496650148827, penalty=l1 ................................
# [CV] ................. C=1291.5496650148827, penalty=l1, total=   7.4s
# [CV] C=1291.5496650148827, penalty=l2 ................................
# [CV] ................. C=1291.5496650148827, penalty=l1, total=   4.9s
# [CV] C=1291.5496650148827, penalty=l2 ................................
# [CV] ................. C=1291.5496650148827, penalty=l1, total=   5.0s
# [CV] C=1291.5496650148827, penalty=l2 ................................
# [CV] ................. C=166.81005372000558, penalty=l2, total=  23.3s
# [CV] C=1291.5496650148827, penalty=l2 ................................
# [CV] ................. C=1291.5496650148827, penalty=l2, total=  17.7s
# [CV] C=1291.5496650148827, penalty=l2 ................................
# [CV] ................. C=1291.5496650148827, penalty=l2, total=  19.7s
# [CV] C=10000.0, penalty=l1 ...........................................
# [CV] ................. C=1291.5496650148827, penalty=l2, total=  18.6s
# [CV] C=10000.0, penalty=l1 ...........................................
# [CV] ................. C=1291.5496650148827, penalty=l2, total=  22.4s
# [CV] C=10000.0, penalty=l1 ...........................................
# [CV] ............................ C=10000.0, penalty=l1, total=   7.8s
# [CV] C=10000.0, penalty=l1 ...........................................
# [CV] ............................ C=10000.0, penalty=l1, total=   9.0s
# [CV] C=10000.0, penalty=l1 ...........................................
# [CV] ............................ C=10000.0, penalty=l1, total=   9.4s
# [CV] C=10000.0, penalty=l2 ...........................................
# [CV] ................. C=1291.5496650148827, penalty=l2, total=  21.9s
# [CV] C=10000.0, penalty=l2 ...........................................
# [CV] ............................ C=10000.0, penalty=l1, total=   6.3s
# [CV] C=10000.0, penalty=l2 ...........................................
# [CV] ............................ C=10000.0, penalty=l1, total=  10.1s
# [CV] C=10000.0, penalty=l2 ...........................................
# [CV] ............................ C=10000.0, penalty=l2, total=  33.8s
# [CV] C=10000.0, penalty=l2 ...........................................
# [CV] ............................ C=10000.0, penalty=l2, total=  28.0s
# [CV] ............................ C=10000.0, penalty=l2, total=  29.3s
# [CV] ............................ C=10000.0, penalty=l2, total=  32.4s
# [CV] ............................ C=10000.0, penalty=l2, total=  16.0s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  4.4min finished

# %%
best_params
# Out:
# {'C': 0.046415888336127774, 'penalty': 'l1'}

# %%
#clf = XGBClassifier(max_depth=16,n_estimators=3000,)
#clf = SVC(gamma=0.001, C=0.1, kernel = 'linear')
clf = LogisticRegression(C=0.046415888336127774, penalty='l1')

# %%
clf.fit(X_train,y_train)
# Out:
# LogisticRegression(C=0.046415888336127774, class_weight=None, dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=1, penalty='l1', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)

# %% [markdown]
# #### Testing Accuracy

# %%
preds_val = clf.predict(X_test)
accuracy = accuracy_score(y_test, preds_val)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 67.78%

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test, preds_val)
# Out:
# array([[622, 340],
#        [275, 672]])

# %%
preds_val.shape
# Out:
# (1909,)

# %%
from sklearn.utils.multiclass import unique_labels
import matplotlib.pyplot as plt
def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    classes = classes[unique_labels(y_true, y_pred)]
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax

# %%
plot_confusion_matrix(y_test, preds_val,np.array(['Non-Eat','Eat']))
# Out:
# Confusion matrix, without normalization
# [[622 340]
#  [275 672]]

# %% [markdown]
# #### Testing with Unbalanced data (77670 samples)

# %%
#print(X_unbalanced_new.shape)
X_unbalanced_new = X_unbalancedData
preds_val_unbalanced = clf.predict(X_unbalanced_new)
accuracy = accuracy_score(Y_unbalancedData, preds_val_unbalanced)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 67.11%

# %%
plot_confusion_matrix(Y_unbalancedData, preds_val_unbalanced,np.array(['Non-Eat','Eat']))
# Out:
# Confusion matrix, without normalization
# [[49804 24625]
#  [  902  2279]]

# %% [markdown]
# ### Training Accuracy

# %%
print(X_train.shape)
preds_val_train = clf.predict(X_train)
accuracy = accuracy_score(y_train, preds_val_train)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# (4453, 255)
# Accuracy: 70.45%

# %%
plot_confusion_matrix(y_train, preds_val_train,np.array(['Non-Eat','Eat']))
# Out:
# Confusion matrix, without normalization
# [[1530  689]
#  [ 627 1607]]

# %% [markdown]
# ## GNB

# %%
#from lightgbm import LGBMClassifier
#model1 = LGBMClassifier(boosting_type='gbdt', num_leaves=31, max_depth=-1, learning_rate=0.1, n_estimators=100, subsample_for_bin=200000, objective=None, class_weight=None, min_split_gain=0.0, min_child_weight=0.001, min_child_samples=20, subsample=1.0, subsample_freq=0, colsample_bytree=1.0, reg_alpha=0.0, reg_lambda=0.0, random_state=42, n_jobs=-1, silent=True, importance_type='split',)
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()

# %%
#from sklearn.model_selection import GridSearchCV
#parameters = {'n_estimators':(100,100,1000), 'max_depth': range(1, 20, 5),}

# %%
#model1.get_params().keys()

# %%
#gs_clf = GridSearchCV(model1,parameters, cv=5, n_jobs=-1,verbose=2)

# %%
print (X_train.shape, y_train.shape)
model = gnb.fit(X_train, y_train)
#model = gs_clf.fit(X_train, y_train)
# Out:
# (4453, 255) (4453,)

# %%
#print(model.best_params_)
#for param_name in sorted(parameters.keys()):
#    print("%s: %r" % (param_name, model.best_params_[param_name]))

# %%
from sklearn.metrics import accuracy_score
preds_val = model.predict(X_test)
accuracy = accuracy_score(y_test, preds_val)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 60.35%

# %%
plot_confusion_matrix(y_test, preds_val,np.array(['Non-Eat','Eat']))
# Out:
# Confusion matrix, without normalization
# [[321 641]
#  [116 831]]

# %% [markdown]
# #### Training Accuracy

# %%
from sklearn.metrics import accuracy_score
preds_val_train = model.predict(X_train)
accuracy = accuracy_score(y_train, preds_val_train)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 61.82%

# %%
plot_confusion_matrix(y_train, preds_val_train,np.array(['Non-Eat','Eat']))
# Out:
# Confusion matrix, without normalization
# [[ 762 1457]
#  [ 243 1991]]

# %% [markdown]
# #### Test with unbalanced data

# %%
from sklearn.metrics import accuracy_score
preds_val = model.predict(X_unbalanced_new)
accuracy = accuracy_score(Y_unbalancedData, preds_val)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 38.36%

# %%
plot_confusion_matrix(Y_unbalancedData, preds_val,np.array(['Non-Eat','Eat']))
# Out:
# Confusion matrix, without normalization
# [[26946 47483]
#  [  359  2822]]

# %% [markdown]
# GPC

# %%
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
kernel = 1.0 * RBF(1.0)
gpc = GaussianProcessClassifier(kernel=kernel, random_state=0,n_jobs = -1)

# %%
print (X_train.shape, y_train.shape)
model = gpc.fit(X_train, y_train)
# Out:
# (4453, 255) (4453,)

# %%
from sklearn.metrics import accuracy_score
preds_val = model.predict(X_test)
accuracy = accuracy_score(y_test, preds_val)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
plot_confusion_matrix(y_test, preds_val,np.array(['Non-Eat','Eat']))
# Out:
# Accuracy: 49.61%
# Confusion matrix, without normalization
# [[  0 962]
#  [  0 947]]

# %% [markdown]
# Training Accuracy

# %%
from sklearn.metrics import accuracy_score
preds_val_train = model.predict(X_train)
accuracy = accuracy_score(y_train, preds_val_train)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
plot_confusion_matrix(y_train, preds_val_train,np.array(['Non-Eat','Eat']))
# Out:
# Accuracy: 50.17%
# Confusion matrix, without normalization
# [[   0 2219]
#  [   0 2234]]

# %% [markdown]
# Test with unbalanced data

# %%
from sklearn.metrics import accuracy_score
preds_val = model.predict(X_unbalanced_new)
accuracy = accuracy_score(Y_unbalancedData, preds_val)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
plot_confusion_matrix(Y_unbalancedData, preds_val,np.array(['Non-Eat','Eat']))
